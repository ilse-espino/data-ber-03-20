# %%
import requests

# %%
url = "https://wikimedia.org/api/rest_v1/metrics/pageviews/aggregate/en.wikipedia.org/all-access/all-agents/daily/20180101/20191231"
headers = {"accept": "application/json"}

resp = requests.get(url, headers=headers)
resp
# Out:
# <Response [200]>

# %%
resp.text
# Out:
# '{"items":[{"project":"en.wikipedia","access":"all-access","agent":"all-agents","granularity":"daily","timestamp":"2018010100","views":302828330},{"project":"en.wikipedia","access":"all-access","agent":"all-agents","granularity":"daily","timestamp":"2018010200","views":319485738},{"project":"en.wikipedia","access":"all-access","agent":"all-agents","granularity":"daily","timestamp":"2018010300","views":322019675},{"project":"en.wikipedia","access":"all-access","agent":"all-agents","granularity":"daily","timestamp":"2018010400","views":314645741},{"project":"en.wikipedia","access":"all-access","agent":"all-agents","granularity":"daily","timestamp":"2018010500","views":310155899},{"project":"en.wikipedia","access":"all-access","agent":"all-agents","granularity":"daily","timestamp":"2018010600","views":316702185},{"project":"en.wikipedia","access":"all-access","agent":"all-agents","granularity":"daily","timestamp":"2018010700","views":324186750},{"project":"en.wikipedia","access":"all-access","agent":"all-agents","granularity":"daily","timestamp":"2018010800","views":335431026},{"project":"en.wikipedia","access":"all-access","agent":"all-agents","granularity":"daily","timestamp":"2018010900","views":321991203},{"project":"en.wikipedia","access":"all-access","agent":"all-agents","granularity":"daily","timestamp":"2018011000","views":318603157},{"project":"en.wikipedia","access":"all-access","agent":"all-agents","granularity":"daily","timestamp":"2018011100","views":327306183},{"project":"en.wikipedia","access":"all-access","agent":"all-agents","granularity":"daily","timestamp":"2018011200","views":308518899},{"project":"en.wikipedia","access":"all-access","agent":"all-agents","granularity":"daily","timestamp":"2018011300","views":314518803},{"project":"en.wikipedia","access":"all-access","agent":"all-agents","granularity":"daily","timestamp":"2018011400","views":341467997},{"project":"en.wikipedia","access":"all-access","agent":"all-agents","granularity":"daily","timestamp":"2018011500","views":346801956},{"project":"en.wikipedia","access":"all-access","agent":"all-agents","granularity":"daily","timestamp":"2018011600","views":332404256},{"project":"en.wikipedia","access":"all-access","agent":"all-agents","granularity":"daily","timestamp":"2018011700","views":329626172},{"project":"en.wikipedia","access":"all-access","agent":"all-agents","granularity":"daily","timestamp":"2018011800","views":346227443},{"project":"en.wikipedia","access":"all-access","agent":"all-agents","granularity":"daily","timestamp":"2018011900","views":316299327},{"project":"en.wikipedia","access":"all-access","agent":"all-agents","granularity":"daily","timestamp":"2018012000","views":303292818},{"project":"en.wikipedia","access":"all-access","agent":"all-agents","granularity":"daily","timestamp":"2018012100","views":326682372},{"project":"en.wikipedia","access":"all-access","agent":"all-agents","granularity":"daily","timestamp":"2018012200","views":341515484},{"project":"en.wikipedia","access":"all-access","agent":"all-agents","granularity":"daily","timestamp":"2018012300","views":329910617},{"project":"en.wikipedia","access":"all-access","agent":"all-agents","granularity":"daily","timestamp":"2018012400","views":321322164},{"project":"en.wikipedia","access":"all-access","agent":"all-agents","granularity":"daily","timestamp":"2018012500","views":316707019},{"project":"en.wikipedia","access":"all-access","agent":"all-agents","granularity":"daily","timestamp":"2018012600","views":310964880},{"project":"en.wikipedia","access":"all-access","agent":"all-agents","granularity":"daily","timestamp":"2018012700","views":308760934},{"project":"en.wikipedia","access":"all-access","agent":"all-agents","granularity":"daily","timestamp":"2018012800","views":325955174},{"project":"en.wikipedia","access":"all-access","agent":"all-agents","granularity":"daily","timestamp":"2018012900","views":337205984},{"project":"en.wikipedia","access":"all-access","agent":"all-agents","gran ...
