# %% [markdown]
# # Job Board Scraping Lab
#
# In this lab you will first see a minimal but fully functional code snippet to scrape the LinkedIn Job Search webpage. You will then work on top of the example code and complete several chanllenges.
#
# ### Some Resources
#
# - [Requests library](http://docs.python-requests.org/en/master/#the-user-guide) documentation
# - [Beautiful Soup Doc](https://www.crummy.com/software/BeautifulSoup/bs4/doc/)
# - [Urllib](https://docs.python.org/3/library/urllib.html#module-urllib)
# - [re lib](https://docs.python.org/3/library/re.html)
# - [Scrapy](https://scrapy.org/)
# - [List of HTTP status codes](https://en.wikipedia.org/wiki/List_of_HTTP_status_codes)
# - [HTML basics](http://www.simplehtmlguide.com/cheatsheet.php)
# - [CSS basics](https://www.cssbasics.com/#page_start)

# %%
# Import the required libraries
import pandas as pd
from bs4 import BeautifulSoup
import requests

"""
This function searches job posts from LinkedIn and converts the results into a dataframe.
"""
def scrape_linkedin_job_search(keywords):
    
    # Define the base url to be scraped.
    # All uppercase variable name signifies this is a constant and its value should never unchange
    BASE_URL = 'https://www.linkedin.com/jobs/search/?'
    
    # Assemble the full url with parameters
    scrape_url = ''.join([BASE_URL, 'keywords=', keywords])

    # Create a request to get the data from the server 
    page = requests.get(scrape_url)
    soup = BeautifulSoup(page.text, 'html.parser')

    # Create an empty dataframe with the columns consisting of the information you want to capture
    columns = ['Title', 'Company', 'Location']
    data = pd.DataFrame(columns=columns)

    # Retrieve HTML code from the webpage. Parse the HTML into a list of "cards".
    # Then in each job card, extract the job title, company, and location data.
    titles = []
    companies = []
    locations = []
    for card in soup.select("div.result-card__contents"):
        title = card.findChild("h3", recursive=False)
        company = card.findChild("h4", recursive=False)
        location = card.findChild("span", attrs={"class": "job-result-card__location"}, recursive=True)
        titles.append(title.string)
        companies.append(company.string)
        locations.append(location.string)
    
    # Inject job titles, companies, and locations into the empty dataframe
    zipped = zip(titles, companies, locations)
    for z in list(zipped):
        data=data.append({'Title' : z[0] , 'Company' : z[1], 'Location': z[2]} , ignore_index=True)
    
    # Return dataframe
    return data

# %%
# Example to call the function

results = scrape_linkedin_job_search('data%20analysis')
results
# Out:
#                                                 Title  \
# 0                                        Data Analyst
# 1                                        Data Analyst
# 2                                        Data Analyst
# 3                                        Data Analyst
# 4                                        Data Analyst
# 5   Data Analyst, Business Analysis and Reporting ...
# 6                                        Data Analyst
# 7                           Data Analytics Consultant
# 8                                  Fraud Data Analyst
# 9                                        Data Analyst
# 10                                       Data Analyst
# 11                                       Data Analyst
# 12                                Analytics Analyst I
# 13                                       Data Analyst
# 14                Data Scientist, Workforce Analytics
# 15                                Junior Data Analyst
# 16                       Data & Analytics Specialist
# 17                                       Data Analyst
# 18                                       Data Analyst
# 19                                       Data Analyst
# 20  Business Intelligence Engineer - 2020 (United ...
# 21                                     Data Scientist
# 22                                       Data Analyst
# 23                                       Data Analyst
# 24                                       Data Analyst
#
#                                        Company  \
# 0                    Live Nation Entertainment
# 1                                        Front
# 2                                        Tesla
# 3                     Goldstone Partners, Inc.
# 4                        Banyan Health Systems
# 5                         Publix Super Markets
# 6                              Bradford & Galt
# 7                           INNOVATO Solutions
# 8                      Abercrombie & Fitch Co.
# 9                                   MNG Health
# 10                                   Microsoft
# 11                                      Google
# 12                                       Modis
# 13                 Incept Data Solutions, Inc.
# 14                  Warner Bros. Entertainment
# 15  Engineering - a Hill International Company
# 16                         Veear Projects Inc.
# 17                                Capacity LLC
# 18                              Woodland Foods
# 19                                      Twitch
# 20                                      Amazon
# 21                                         CNN
# 22                          Reliance One, Inc.
# 23                Cooper Tire & Rubber Company
# 24                          Cortex Consultants
#
#                            Location
# 0                   Los Angeles, CA
# 1                 San Francisco, CA
# 2                       Fremont, CA
# 3                       Boulder, CO
# 4           Miami Metropolitan Area
# 5                      Lakeland, FL
# 6                      St Louis, MO
# 7                 San Francisco, CA
# 8                      Columbus, OH
# 9              Greater Philadelphia
# 10                      Redmond, WA
# 11                Mountain View, CA
# 12                   Wilmington, DE
# 13                     Sterling, VA
# 14                      Burbank, CA
# 15                    Allendale, NJ
# 16          South San Francisco, CA
# 17              North Brunswick, NJ
# 18                     Waukegan, IL
# 19                San Francisco, CA
# 20                      Seattle, WA
# 21  New York City Metropolitan Area
# 22                   Georgetown, KY
# 23                      Findlay, OH
# 24                       Summit, NJ

# %% [markdown]
# ## Challenge 1
#
# The first challenge for you is to update the `scrape_linkedin_job_search` function by adding a new parameter called `num_pages`. This will allow you to search more than 25 jobs with this function. Suggested steps:
#
# 1. Go to https://www.linkedin.com/jobs/search/?keywords=data%20analysis in your browser.
# 1. Scroll down the left panel and click the page 2 link. Look at how the URL changes and identify the page offset parameter.
# 1. Add `num_pages` as a new param to the `scrape_linkedin_job_search` function. Update the function code so that it uses a "for" loop to retrieve several pages of search results.
# 1. Test your new function by scraping 5 pages of the search results.
#
# Hint: Prepare for the case where there are less than 5 pages of search results. Your function should be robust enough to **not** trigger errors. Simply skip making additional searches and return all results if the search already reaches the end.

# %%
# your code here

# Import the required libraries
import pandas as pd
from bs4 import BeautifulSoup
import requests

"""
This function searches job posts from LinkedIn and converts the results into a dataframe.
"""
def scrape_linkedin_job_search(keywords, num_pages):
    
    # Define the base url to be scraped.
    # All uppercase variable name signifies this is a constant and its value should never unchange
    
    BASE_URL = 'https://www.linkedin.com/jobs/search/?'
    scrape_url = ''.join([BASE_URL, 'keywords=', keywords])    
    urls=[]
    for i in range(num_pages):
        if i>= 1:
            urls.append(''.join([scrape_url,"&start=", str(i*25)]))
        else:
            urls.append(scrape_url)
            
    
    # Create an empty dataframe with the columns consisting of the information you want to capture
    columns = ['Title', 'Company', 'Location']
    data = pd.DataFrame(columns=columns)

    # Create a request to get the data from the server
    titles = []
    companies = []
    locations = []    
    for url in urls:
        page = requests.get(url)
        soup = BeautifulSoup(page.text, 'html.parser')
    # Retrieve HTML code from the webpage. Parse the HTML into a list of "cards".
    # Then in each job card, extract the job title, company, and location data.
        for card in soup.select("div.result-card__contents"):
            title = card.findChild("h3", recursive=False)
            company = card.findChild("h4", recursive=False)
            location = card.findChild("span", attrs={"class": "job-result-card__location"}, recursive=True)
            titles.append(title.string)
            companies.append(company.string)
            locations.append(location.string)
    
    # Inject job titles, companies, and locations into the empty dataframe
    zipped = zip(titles, companies, locations)
    for z in list(zipped):
        data=data.append({'Title' : z[0] , 'Company' : z[1], 'Location': z[2]} , ignore_index=True)
    
    # Return dataframe
    return data

# %%
urls = (['https://www.linkedin.com/jobs/search/?keywords=data%20analysis',
  'https://www.linkedin.com/jobs/search/?keywords=data%20analysis&start=25',
  'https://www.linkedin.com/jobs/search/?keywords=data%20analysis&start=50'])

for url in urls:
    page = requests.get(url)
    print(page.url)

# titles = []
# companies = []
# locations = []    
# for url in urls:
#     page = requests.get(url)
#     soup = BeautifulSoup(page.text, 'html.parser')
#     # Retrieve HTML code from the webpage. Parse the HTML into a list of "cards".
#     # Then in each job card, extract the job title, company, and location data.
#     for card in soup.select("div.result-card__contents"):
#         title = card.findChild("h3", recursive=False)
#         company = card.findChild("h4", recursive=False)
#         location = card.findChild("span", attrs={"class": "job-result-card__location"}, recursive=True)
#         titles.append(title.string)
#         companies.append(company.string)
#         locations.append(location.string)
        
# titles
# Out:
# https://www.linkedin.com/jobs/search/?keywords=data%20analysis
# https://www.linkedin.com/jobs/search/?keywords=data+analysis&start=0
# https://www.linkedin.com/jobs/search/?keywords=data+analysis&start=0

# %%
scrape_linkedin_job_search('data%20analysis',2)
# Out:
#                                                 Title  \
# 0                                        Data Analyst
# 1                                        Data Analyst
# 2                                        Data Analyst
# 3                                        Data Analyst
# 4                                        Data Analyst
# 5                                        Data Analyst
# 6   Data Analyst, Business Analysis and Reporting ...
# 7                                        Data Analyst
# 8                                  Fraud Data Analyst
# 9                           Data Analytics Consultant
# 10                                       Data Analyst
# 11                                       Data Analyst
# 12                                Analytics Analyst I
# 13                                       Data Analyst
# 14                Data Scientist, Workforce Analytics
# 15                       Data & Analytics Specialist
# 16                                       Data Analyst
# 17                                       Data Analyst
# 18  Business Intelligence Engineer - 2020 (United ...
# 19                                     Data Scientist
# 20                                       Data Analyst
# 21                                       Data Analyst
# 22                                       Data Analyst
# 23                                       Data Analyst
# 24                                       Data Analyst
# 25                                       Data Analyst
# 26                                       Data Analyst
# 27                                       Data Analyst
# 28                                       Data Analyst
# 29                                       Data Analyst
# 30                                       Data Analyst
# 31  Data Analyst, Business Analysis and Reporting ...
# 32                                       Data Analyst
# 33                                 Fraud Data Analyst
# 34                          Data Analytics Consultant
# 35                                       Data Analyst
# 36                                       Data Analyst
# 37                                Analytics Analyst I
# 38                                       Data Analyst
# 39                Data Scientist, Workforce Analytics
# 40                       Data & Analytics Specialist
# 41                                       Data Analyst
# 42                                       Data Analyst
# 43  Business Intelligence Engineer - 2020 (United ...
# 44                                     Data Scientist
# 45                                       Data Analyst
# 46                                       Data Analyst
# 47                                       Data Analyst
# 48                                       Data Analyst
# 49                                       Data Analyst
#
#                          Company                         Location
# 0      Live Nation Entertainment                  Los Angeles, CA
# 1                          FRONT                San Francisco, CA
# 2                          Front                San Francisco, CA
# 3                          Tesla                      Fremont, CA
# 4       Goldstone Partners, Inc.                      Boulder, CO
# 5          Banyan Health Systems          Miami Metropolitan Area
# 6           Publix Super Markets                     Lakeland, FL
# 7                Bradford & Galt                     St Louis, MO
# 8        Abercrombie & Fitch Co.                     Columbus, OH
# 9             INNOVATO Solutions                San Francisco, CA
# 10                    MNG Health             Greater Philadelphia
# 11                        Google                Mountain View, CA
# 12                         Modis                   Wilmington, DE
# 13   Incept Data Solutions, Inc.                     Sterling, VA
# 14    Warner Bros. Entertainment                      Burbank, CA
# 15           Veear Projects Inc.          South San Francisco, CA
# 16                  Capacity LLC              North Brunswick, NJ
# 17                        Twitch                San Francisco, CA
# 18                        Amazon                      Seattle, WA
# 19                           CNN  New York City Metropolitan Area
# 20            Reliance One, Inc.                   Georgetown, KY
# 21  Cooper Tire & Rubber Company                      Findlay, OH
# 22                Woodland Foods                     Waukegan, IL
# 23            Cortex Consultants                       Summit, NJ
# 24                  Tech Finders             Greater Phoenix Area
# 25     Live Nation Entertainment                  Los Angeles, CA
# 26                         FRONT                San Francisco, CA
# 27                         Front                San Francisco, CA
# 28                         Tesla                      Fremont, CA
# 29      Goldstone Partners, Inc.                      Boulder, CO
# 30         Banyan Health Systems          Miami Metropolitan Area
# 31          Publix Super Markets                     Lakeland, FL
# 32               Bradford & Galt                     St Louis, MO
# 33       Abercrombie & Fitch Co.                     Columbus, OH
# 34            INNOVATO Solutions                San Francisco, CA
# 35                    MNG Health             Greater Philadelphia
# 36                        Google                Mountain View, CA
# 37                         Modis                   Wilmington, DE
# 38   Incept Data Solutions, Inc.                     Sterling, VA
# 39    Warner Bros. Entertainment                      Burbank, CA
# 40           Veear Projects Inc.          South San Francisco, CA
# 41                  Capacity LLC              North Brunswick, NJ
# 42                        Twitch                San Francisco, CA
# 43                        Amazon                      Seattle, WA
# 44                           CNN  New York City Metropolitan Area
# 45            Reliance One, Inc.                   Georgetown, KY
# 46  Cooper Tire & Rubber Company                      Findlay, OH
# 47                Woodland Foods                     Waukegan, IL
# 48            Cortex Consultants                       Summit, NJ
# 49                  Tech Finders             Greater Phoenix Area

# %% [markdown]
# ## Challenge 2
#
# Further improve your function so that it can search jobs in a specific country. Add the 3rd param to your function called `country`. The steps are identical to those in Challange 1.

# %%
# your code here

# Import the required libraries
import pandas as pd
from bs4 import BeautifulSoup
import requests

"""
This function searches job posts from LinkedIn and converts the results into a dataframe.
"""
def scrape_linkedin_job_search(keywords, num_pages, country):
    
    # Define the base url to be scraped.
    # All uppercase variable name signifies this is a constant and its value should never unchange
    
    BASE_URL = 'https://www.linkedin.com/jobs/search/?'
    scrape_url = ''.join([BASE_URL, 'keywords=', keywords])    
    urls=[]
    for i in range(num_pages):
        if i>= 1:
            urls.append(''.join([scrape_url,"&start=", str(i*25)]))
        else:
            urls.append(scrape_url)
            
    
    # Create an empty dataframe with the columns consisting of the information you want to capture
    columns = ['Title', 'Company', 'Location']
    data = pd.DataFrame(columns=columns)

    # Create a request to get the data from the server
    titles = []
    companies = []
    locations = []    
    for url in urls:
        page = requests.get(url)
        soup = BeautifulSoup(page.text, 'html.parser')
    # Retrieve HTML code from the webpage. Parse the HTML into a list of "cards".
    # Then in each job card, extract the job title, company, and location data.
        for card in soup.select("div.result-card__contents"):
            title = card.findChild("h3", recursive=False)
            company = card.findChild("h4", recursive=False)
            location = card.findChild("span", attrs={"class": "job-result-card__location"}, recursive=True)
            titles.append(title.string)
            companies.append(company.string)
            locations.append(location.string)
    
    # Inject job titles, companies, and locations into the empty dataframe
    zipped = zip(titles, companies, locations)
    for z in list(zipped):
        data=data.append({'Title' : z[0] , 'Company' : z[1], 'Location': z[2]} , ignore_index=True)
    
    # Return dataframe
    return data

# %%
import pandas as pd
from bs4 import BeautifulSoup
import requests

url = "https://www.linkedin.com/jobs/search/?"
soup = bs4.BeautifulSoup((requests.get(url).content), "html.parser")

soup.body.find("div", class_="results__container results__container--two-pane")
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-11-c3e8bc42af4a> in <module>
#       6 soup = bs4.BeautifulSoup((requests.get(url).content), "html.parser")
#       7
# ----> 8 soup.body.find("div", class_="results__container results__container--two-pane").text
#
# AttributeError: 'NoneType' object has no attribute 'text'

# %% [markdown]
# ## Challenge 3
#
# Add the 4th param called `num_days` to your function to allow it to search jobs posted in the past X days. Note that in the LinkedIn job search the searched timespan is specified with the following param:
#
# ```
# f_TPR=r259200
# ```
#
# The number part in the param value is the number of seconds. 259,200 seconds equal to 3 days. You need to convert `num_days` to number of seconds and supply that info to LinkedIn job search.

# %%
# your code here

# %% [markdown]
# ## Bonus Challenge
#
# Allow your function to also retrieve the "Seniority Level" of each job searched. Note that the Seniority Level info is not in the initial search results. You need to make a separate search request for each job card based on the `currentJobId` value which you can extract from the job card HTML.
#
# After you obtain the Seniority Level info, update the function and add it to a new column of the returned dataframe.

# %%
# your code here
