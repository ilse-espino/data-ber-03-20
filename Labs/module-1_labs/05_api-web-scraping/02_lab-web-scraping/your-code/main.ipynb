# %% [markdown]
# # Web Scraping Lab
#
# You will find in this notebook some scrapy exercises to practise your scraping skills.
#
# **Tips:**
#
# - Check the response status code for each request to ensure you have obtained the intended contennt.
# - Print the response text in each request to understand the kind of info you are getting and its format.
# - Check for patterns in the response text to extract the data/info requested in each question.
# - Visit each url and take a look at its source through Chrome DevTools. You'll need to identify the html tags, special class names etc. used for the html content you are expected to extract.

# %% [markdown]
# - [Requests library](http://docs.python-requests.org/en/master/#the-user-guide) documentation
# - [Beautiful Soup Doc](https://www.crummy.com/software/BeautifulSoup/bs4/doc/)
# - [Urllib](https://docs.python.org/3/library/urllib.html#module-urllib)
# - [re lib](https://docs.python.org/3/library/re.html)
# - [lxml lib](https://lxml.de/)
# - [Scrapy](https://scrapy.org/)
# - [List of HTTP status codes](https://en.wikipedia.org/wiki/List_of_HTTP_status_codes)
# - [HTML basics](http://www.simplehtmlguide.com/cheatsheet.php)
# - [CSS basics](https://www.cssbasics.com/#page_start)

# %% [markdown]
# #### Below are the libraries and modules you may need. `requests`,  `BeautifulSoup` and `pandas` are imported for you. If you prefer to use additional libraries feel free to uncomment them.

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd
# from pprint import pprint
# from lxml import html
# from lxml.html import fromstring
# import urllib.request
# from urllib.request import urlopen
import random
import re
# import scrapy

# %% [markdown]
# #### Download, parse (using BeautifulSoup), and print the content from the Trending Developers page from GitHub:

# %%
# This is the url you will scrape in this exercise
url = 'https://github.com/trending/developers'
resp = requests.get(url)

# %%
#your code

soup = BeautifulSoup(resp.content, "html.parser")
soup
# Out:
# <!DOCTYPE html>
#
# <html lang="en">
# <head>
# <meta charset="utf-8"/>
# <link href="https://github.githubassets.com" rel="dns-prefetch"/>
# <link href="https://avatars0.githubusercontent.com" rel="dns-prefetch"/>
# <link href="https://avatars1.githubusercontent.com" rel="dns-prefetch"/>
# <link href="https://avatars2.githubusercontent.com" rel="dns-prefetch"/>
# <link href="https://avatars3.githubusercontent.com" rel="dns-prefetch"/>
# <link href="https://github-cloud.s3.amazonaws.com" rel="dns-prefetch"/>
# <link href="https://user-images.githubusercontent.com/" rel="dns-prefetch"/>
# <link crossorigin="anonymous" href="https://github.githubassets.com/assets/frameworks-146fab5ea30e8afac08dd11013bb4ee0.css" integrity="sha512-FG+rXqMOivrAjdEQE7tO4BwM1poGmg70hJFTlNSxjX87grtrZ6UnPR8NkzwUHlQEGviu9XuRYeO8zH9YwvZhdg==" media="all" rel="stylesheet">
# ...

# %% [markdown]
# #### Display the names of the trending developers retrieved in the previous step.
#
# Your output should be a Python list of developer names. Each name should not contain any html tag.
#
# **Instructions:**
#
# 1. Find out the html tag and class names used for the developer names. You can achieve this using Chrome DevTools.
#
# 1. Use BeautifulSoup to extract all the html elements that contain the developer names.
#
# 1. Use string manipulation techniques to replace whitespaces and linebreaks (i.e. `\n`) in the *text* of each html element. Use a list to store the clean names.
#
# 1. Print the list of names.
#
# Your output should look like below:
#
# ```
# ['trimstray (@trimstray)',
#  'joewalnes (JoeWalnes)',
#  'charlax (Charles-AxelDein)',
#  'ForrestKnight (ForrestKnight)',
#  'revery-ui (revery-ui)',
#  'alibaba (Alibaba)',
#  'Microsoft (Microsoft)',
#  'github (GitHub)',
#  'facebook (Facebook)',
#  'boazsegev (Bo)',
#  'google (Google)',
#  'cloudfetch',
#  'sindresorhus (SindreSorhus)',
#  'tensorflow',
#  'apache (TheApacheSoftwareFoundation)',
#  'DevonCrawford (DevonCrawford)',
#  'ARMmbed (ArmMbed)',
#  'vuejs (vuejs)',
#  'fastai (fast.ai)',
#  'QiShaoXuan (Qi)',
#  'joelparkerhenderson (JoelParkerHenderson)',
#  'torvalds (LinusTorvalds)',
#  'CyC2018',
#  'komeiji-satori (神楽坂覚々)',
#  'script-8']
#  ```

# %%
#your code

# developers = (soup.find("div", class_="application-main")
#               .find("div", class_="Box"))
# #              .find_all("div", class_="col-sm-8 d-md-flex")
# #              .find_all("h1", class_="h3 lh-condensed"))
# developers = developers.find_all("div", class_="col-sm-8 d-md-flex")
# developers = developers.find_all("h1", class_="h3 lh-condensed")
# developers

developers = soup.find_all("h1", class_="h3 lh-condensed")
developers_lst = [developer.text.replace("\n", "").replace(" ","") for developer in developers]
#developers_lst

account = soup.find_all("p", class_="f4 text-normal mb-1")
accounts = [user.text.replace("\n", "").replace(" ","") for user in account]
#accounts

trending_developers = [developers_lst[i] + " (" + accounts[i] + ")" for i in range(len(developers_lst))]

trending_developers
# Out:
# ['FranckNijhof (frenck)',
#  'MichielBorkent (borkdude)',
#  'StéphaneLepin (Palakis)',
#  'YangshunTay (yangshun)',
#  'DavidPeter (sharkdp)',
#  'MaxDesiatov (MaxDesiatov)',
#  'ArvidNorberg (arvidn)',
#  'Erick(CptBlackPixel) (erickzanardo)',
#  'HangZhang (zhanghang1989)',
#  'DotanSimha (dotansimha)',
#  'JamesMills (prologic)',
#  'pancake (radare)',
#  'Lipis (lipis)',
#  'Ken’ichiroOyama (k1LoW)',
#  'DavidTolnay (dtolnay)',
#  'IgorPečovnik (igorpecovnik)',
#  'GrahamCampbell (GrahamCampbell)',
#  'SebastiánRamírez (tiangolo)',
#  'ByungjinPark (posquit0)',
#  'TomPayne (twpayne)',
#  'Liu-ChengXu (liuchengxu)',
#  'FlorentCHAMPIGNY (florent37)',
#  'ChristopherRackauckas (ChrisRackauckas)',
#  'HajimeHoshi (hajimehoshi)',
#  'AlexeyPyltsyn (lex111)']

# %% [markdown]
# #### Display the trending Python repositories in GitHub
#
# The steps to solve this problem is similar to the previous one except that you need to find out the repository names instead of developer names.

# %%
# This is the url you will scrape in this exercise
url = 'https://github.com/trending/python?since=daily'

# %%
#your code

soup_repos = BeautifulSoup(requests.get(url).content, "html.parser")

repos = soup_repos.find_all("h1", class_="h3 lh-condensed")
repos_lst = [repo.text.replace("\n", "").replace(" ", "") for repo in repos]
repos_lst
# Out:
# ['pcomputo/Whole-Foods-Delivery-Slot',
#  'lyhue1991/eat_tensorflow2_in_30_days',
#  'scikit-learn/scikit-learn',
#  'alex04072000/ObstructionRemoval',
#  'ytdl-org/youtube-dl',
#  'StevenBlack/hosts',
#  'quantopian/zipline',
#  'python/cpython',
#  'ProteGO-app/backend',
#  'TheAlgorithms/Python',
#  'xingyizhou/CenterTrack',
#  'CorentinJ/Real-Time-Voice-Cloning',
#  'senguptaumd/Background-Matting',
#  'keras-team/keras',
#  'PaddlePaddle/PaddleSlim',
#  'kivy/kivy',
#  'covid-projections/covid-data-model',
#  'sherlock-project/sherlock',
#  'lazyprogrammer/machine_learning_examples',
#  'donnemartin/system-design-primer',
#  'instabot-py/instabot.py',
#  'python-telegram-bot/python-telegram-bot',
#  'freqtrade/freqtrade',
#  'openai/gym',
#  'yunjey/pytorch-tutorial']

# %% [markdown]
# #### Display all the image links from Walt Disney wikipedia page

# %%
# This is the url you will scrape in this exercise
url = 'https://en.wikipedia.org/wiki/Walt_Disney'

# %%
#your code

disney_soup = BeautifulSoup(requests.get(url).content, "html.parser")
disney_imgs = disney_soup.find_all(class_="image", href=True)
img_urls = [str(pic.find("img").get("src")) for pic in disney_imgs]

img_urls
# Out:
# ['//upload.wikimedia.org/wikipedia/commons/thumb/d/df/Walt_Disney_1946.JPG/220px-Walt_Disney_1946.JPG',
#  '//upload.wikimedia.org/wikipedia/commons/thumb/8/87/Walt_Disney_1942_signature.svg/150px-Walt_Disney_1942_signature.svg.png',
#  '//upload.wikimedia.org/wikipedia/commons/thumb/c/c4/Walt_Disney_envelope_ca._1921.jpg/220px-Walt_Disney_envelope_ca._1921.jpg',
#  '//upload.wikimedia.org/wikipedia/commons/thumb/0/0d/Trolley_Troubles_poster.jpg/170px-Trolley_Troubles_poster.jpg',
#  '//upload.wikimedia.org/wikipedia/commons/thumb/7/71/Walt_Disney_and_his_cartoon_creation_%22Mickey_Mouse%22_-_National_Board_of_Review_Magazine.jpg/170px-Walt_Disney_and_his_cartoon_creation_%22Mickey_Mouse%22_-_National_Board_of_Review_Magazine.jpg',
#  '//upload.wikimedia.org/wikipedia/en/thumb/4/4e/Steamboat-willie.jpg/170px-Steamboat-willie.jpg',
#  '//upload.wikimedia.org/wikipedia/commons/thumb/5/57/Walt_Disney_1935.jpg/170px-Walt_Disney_1935.jpg',
# ...

# %% [markdown]
# #### Retrieve an arbitary Wikipedia page of "Python" and create a list of links on that page

# %%
# This is the url you will scrape in this exercise
url ='https://en.wikipedia.org/wiki/Python'

# %%
#your code

python_soup = BeautifulSoup(requests.get(url).content, "html.parser")
python_urls = (python_soup.find("div", id="bodyContent", class_="mw-body-content")
                           .find_all(href=True))

python_urls_lst = [str(link.get("href")) for link in python_urls]
python_urls_lst
# Out:
# ['#mw-head',
#  '#p-search',
#  'https://en.wiktionary.org/wiki/Python',
#  'https://en.wiktionary.org/wiki/python',
#  '#Snakes',
#  '#Ancient_Greece',
#  '#Media_and_entertainment',
#  '#Computing',
#  '#Engineering',
#  '#Roller_coasters',
#  '#Vehicles',
#  '#Weaponry',
#  '#People',
#  '#Other_uses',
#  '#See_also',
#  '/w/index.php?title=Python&action=edit&section=1',
#  '/wiki/Pythonidae',
#  '/wiki/Python_(genus)',
#  '/w/index.php?title=Python&action=edit&section=2',
#  '/wiki/Python_(mythology)',
#  '/wiki/Python_of_Aenus',
#  '/wiki/Python_(painter)',
#  '/wiki/Python_of_Byzantium',
#  '/wiki/Python_of_Catana',
#  '/w/index.php?title=Python&action=edit&section=3',
#  '/wiki/Python_(film)',
#  '/wiki/Pythons_2',
#  '/wiki/Monty_Python',
#  '/wiki/Python_(Monty)_Pictures',
#  '/w/index.php?title=Python&action=edit&section=4',
#  '/wiki/Python_(programming_language)',
#  '/wiki/CPython',
#  '/wiki/CMU_Common_Lisp',
#  '/wiki/PERQ#PERQ_3',
# ...

# %% [markdown]
# #### Number of Titles that have changed in the United States Code since its last release point

# %%
# This is the url you will scrape in this exercise
url = 'http://uscode.house.gov/download/download.shtml'

# %%
#your code

soup_us_titles = BeautifulSoup(requests.get(url).content, "html.parser")

changed_titles_lst = soup_us_titles.find_all("div", class_="usctitlechanged")

changed_titles = [title.text.replace("\n", "").strip() for title in changed_titles_lst]

changed_titles
# Out:
# ['Title 8 - Aliens and Nationality',
#  'Title 22 - Foreign Relations and Intercourse',
#  'Title 29 - Labor',
#  'Title 42 - The Public Health and Welfare']

# %% [markdown]
# #### A Python list with the top ten FBI's Most Wanted names

# %%
# This is the url you will scrape in this exercise
url = 'https://www.fbi.gov/wanted/topten'

# %%
#your code

names_soup = BeautifulSoup(requests.get(url).content, "html.parser")

names = (names_soup.find("ul", class_="full-grid wanted-grid-natural infinity castle-grid-block-xs-2 castle-grid-block-sm-2castle-grid-block-md-3 castle-grid-block-lg-5 dt-grid")
                    .find_all("h3", class_="title"))

top_10_fbi = [name.text.replace("\n","") for name in names]

top_10_fbi
# Out:
# ['ALEXIS FLORES',
#  'EUGENE PALMER',
#  'SANTIAGO VILLALBA MEDEROS',
#  'RAFAEL CARO-QUINTERO',
#  'ROBERT WILLIAM FISHER',
#  'BHADRESHKUMAR CHETANBHAI PATEL',
#  'ALEJANDRO ROSALES CASTILLO',
#  'ARNOLDO JIMENEZ',
#  'YASER ABDEL SAID',
#  'JASON DEREK BROWN']

# %% [markdown]
# ####  20 latest earthquakes info (date, time, latitude, longitude and region name) by the EMSC as a pandas dataframe

# %%
# This is the url you will scrape in this exercise
url = 'https://www.emsc-csem.org/Earthquake/'

# %%
#your code
earthquakes_soup = BeautifulSoup(requests.get(url).content, "html.parser")
earthquakes_data = (earthquakes_soup.body
                     .find("div", id="contenu")
                     .find("div", id="content")
                     .find("tbody", id="tbody")
                     .find_all("tr"))

#earthquakes_data[0].find("td", class_="tabev6")

date_data = [row.find("td", class_="tabev6") for row in earthquakes_data]
date_data = [date_data[i].text.replace("earthquake","").replace("min ago","").replace("\xa0","") for i in range(len(date_data))]

latitude_data = [row.find("td", class_="tabev1") for row in earthquakes_data]
latitude_data_c = [row.find("td", class_="tabev2") for row in earthquakes_data]
latitude_data_c = [latitude_data_c[i].text.replace("\xa0","") for i in range(len(latitude_data_c))]
latitude_data = [latitude_data[i].text.replace("\xa0","") for i in range(len(latitude_data))]
latitude_data = [str(latitude_data[i]) + " "+ str(latitude_data_c[i]) for i in range(len(latitude_data))]

longitude_data = [row.find_all("td", class_="tabev1")[1] for row in earthquakes_data]
longitude_data_c = [row.find_all("td", class_="tabev2")[1] for row in earthquakes_data]
longitude_data_c = [longitude_data_c[i].text.replace("\xa0","") for i in range(len(longitude_data_c))]
longitude_data = [longitude_data[i].text.replace("\xa0","") for i in range(len(longitude_data))]
longitude_data = [str(longitude_data[i]) + " "+ str(longitude_data_c[i]) for i in range(len(longitude_data))]

region_data = [row.find("td", class_="tb_region") for row in earthquakes_data]
region_data = [region_data[i].text.replace("\xa0","") for i in range(len(region_data))]

earthquakes_dict = {"date": date_data,
                   "latitude": latitude_data,
                   "longitude": longitude_data,
                   "region": region_data}

pd.DataFrame(earthquakes_dict).head(10)
# Out:
#                          date latitude longitude  \
# 0      2020-04-0617:49:11.416  47.82 N  121.98 W
# 1      2020-04-0617:41:30.024  41.36 N   20.15 E
# 2      2020-04-0617:33:54.031   1.01 N   99.56 E
# 3      2020-04-0617:16:48.048   2.45 S  121.41 E
# 4      2020-04-0617:06:26.359  17.93 N   66.84 W
# 5  2020-04-0616:58:57.01hr 06   3.79 N   97.62 E
# 6  2020-04-0616:51:58.51hr 13  17.93 N   66.61 W
# 7  2020-04-0616:44:55.01hr 20   0.69 N  126.21 E
# 8  2020-04-0616:41:36.01hr 23   0.84 N  125.41 E
# 9  2020-04-0616:34:06.81hr 31  33.23 N  117.55 W
#
#                             region
# 0  SEATTLE-TACOMA AREA, WASHINGTON
# 1                          ALBANIA
# 2      NORTHERN SUMATRA, INDONESIA
# 3              SULAWESI, INDONESIA
# 4               PUERTO RICO REGION
# 5      NORTHERN SUMATRA, INDONESIA
# 6               PUERTO RICO REGION
# 7                      MOLUCCA SEA
# 8                      MOLUCCA SEA
# 9   GULF OF SANTA CATALINA, CALIF.

# %% [markdown]
# #### Display the date, days, title, city, country of next 25 hackathon events as a Pandas dataframe table

# %%
# This is the url you will scrape in this exercise
url ='https://hackevents.co/hackathons'

# %%
#your code

hackathon_

# %% [markdown]
# #### Count number of tweets by a given Twitter account.

# %% [markdown]
# You will need to include a ***try/except block*** for account names not found.
# <br>***Hint:*** the program should count the number of tweets for any provided account

# %%
# This is the url you will scrape in this exercise 
# You will need to add the account credentials to this url
url = 'https://twitter.com/ilseespino'

# %%
#your code

twitter_soup = BeautifulSoup(requests.get(url).content, "html.parser")
twitter_soup
# Out:
# <!DOCTYPE html>
#
# <html data-scribe-reduced-action-queue="true" lang="de">
# <head>
# <meta charset="utf-8"/>
# <script nonce="1upZhJpRquNZ7expbYGl5w==">
#         !function(){window.initErrorstack||(window.initErrorstack=[]),window.onerror=function(r,i,n,o,t){r.indexOf("Script error.")>-1||window.initErrorstack.push({errorMsg:r,url:i,lineNumber:n,column:o,errorObj:t})}}();
#       </script>
# <script id="bouncer_terminate_iframe" nonce="1upZhJpRquNZ7expbYGl5w==">
#     if (window.top != window) {
#   window.top.postMessage({'bouncer': true, 'event': 'complete'}, '*');
# }
#   </script>
# <script id="swift_action_queue" nonce="1upZhJpRquNZ7expbYGl5w==">
# ...

# %% [markdown]
# #### Number of followers of a given twitter account

# %% [markdown]
# You will need to include a ***try/except block*** in case account/s name not found.
# <br>***Hint:*** the program should count the followers for any provided account

# %%
# This is the url you will scrape in this exercise 
# You will need to add the account credentials to this url
url = 'https://twitter.com/ilseespino'

# %%
#your code

twitter_soup = BeautifulSoup(requests.get(url).content, "html.parser")
twitter_soup

try:
    follow_box = twitter_soup.find('li',{'class':'ProfileNav-item ProfileNav-item--followers'})
    followers = follow_box.find('a').find('span',{'class':'ProfileNav-value'})
    print("Number of followers: {} ".format(followers.get('data-count')))
except:
    print('Account name not found.')
#twitter_soup.body.find("main", class_="css-1dbjc4n r-1oszu61 r-16y2uox r-1wbh5a2 r-13qz1uu")
#.find("div", class_="css-1dbjc4n").find("div", class_="css-1dbjc4n r-ku1wi2 r-1j3t67a r-m611by").find("div", class_="css-1dbjc4n r-18u37iz").find("span", class_="css-901oao css-16my406 r-1qd0xha r-vw2c0b r-ad9z0x r-bcqeeo r-qvutc0")
# Out:
# Number of followers: 306

# %% [markdown]
# #### List all language names and number of related articles in the order they appear in wikipedia.org

# %%
# This is the url you will scrape in this exercise
url = 'https://www.wikipedia.org/'

# %%
#your code

# %% [markdown]
# #### A list with the different kind of datasets available in data.gov.uk

# %%
# This is the url you will scrape in this exercise
url = 'https://data.gov.uk/'

# %%
#your code

# %% [markdown]
# #### Top 10 languages by number of native speakers stored in a Pandas Dataframe

# %%
# This is the url you will scrape in this exercise
url = 'https://en.wikipedia.org/wiki/List_of_languages_by_number_of_native_speakers'

# %%
#your code

# %% [markdown]
# ### BONUS QUESTIONS

# %% [markdown]
# #### Scrape a certain number of tweets of a given Twitter account.

# %%
# This is the url you will scrape in this exercise 
# You will need to add the account credentials to this url
url = 'https://twitter.com/'

# %%
# your code

# %% [markdown]
# #### IMDB's Top 250 data (movie name, Initial release, director name and stars) as a pandas dataframe

# %%
# This is the url you will scrape in this exercise 
url = 'https://www.imdb.com/chart/top'

# %%
# your code

# %% [markdown]
# #### Movie name, year and a brief summary of the top 10 random movies (IMDB) as a pandas dataframe.

# %%
#This is the url you will scrape in this exercise
url = 'http://www.imdb.com/chart/top'

# %%
#your code

# %% [markdown]
# #### Find the live weather report (temperature, wind speed, description and weather) of a given city.

# %%
#https://openweathermap.org/current
city = city=input('Enter the city:')
url = 'http://api.openweathermap.org/data/2.5/weather?'+'q='+city+'&APPID=b35975e18dc93725acb092f7272cc6b8&units=metric'

# %%
# your code

# %% [markdown]
# #### Book name,price and stock availability as a pandas dataframe.

# %%
# This is the url you will scrape in this exercise. 
# It is a fictional bookstore created to be scraped. 
url = 'http://books.toscrape.com/'

# %%
#your code
